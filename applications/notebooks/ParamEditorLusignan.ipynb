# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
#parfile='/Users/jinyuntang/work/github/ecosim_tests_by_others/new-data/input-nc-files/pft-lusignan.nc'
#parfile='/Users/jinyuntang/work/github/EcoSIM/input_data/ecosim_pftpar_20251224.nc'
parfile='/Users/jinyuntang/work/ibi/grass_clova_pftpar.nc'
parEditor=ParEditor(pftparfile=parfile)
#parEditor.CopyPlantPft("clvs35",'clvs32')

# %%
pft='gr3s32'

print(pft)
pars={'CHL':0.20,'RUBP':0.30,'ETMX':500,'SLA1':0.008,'UPMXZO':0.005,'UPMXZH':0.006,'UPKMZH':10,'UPKMZO':25,'VCMX':70,'CFI':0.9,'IWTYP':1,
      'RSRA':200000000,'RSRR':10000,'RTFQ':600,'PTSHT':2.e-2,'RCS':0.2,'IGTYP':1,'CNWL':2.8,'CPWL':42.,'CNWR':2.3,'CPWR':28.0,'VRNXI':1200,
     'FCO2':0.7,'RRAD2M':0.1e-3,'RRAD1M':0.3e-3,'GRMX':3.e-4,'PORT':0.1,'WDLF':20,'ANGSH':75,'ZTYPI':2,'CTC':-5,'PhiMEAN':0.05,'GROUPX':10.,
     'XRNI':2.0e-3,'XRLA':2.0e-3,'SNL1':0.35,'SSL1':0.2,'IEBTYP':3}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# gr3s32
# /Users/jinyuntang/work/ibi/grass_clova_pftpar.nc
# Fraction of leaf protein binded with chlorophyll                                                    : CHL for gr3s32 is 0.25, and changed to 0.2
# growth in leaf area vs mass                                                                         : SLA1 for gr3s32 is 0.004999999888241291, and changed to 0.008
# specific C3 rubisco carboxylase                                                                     : VCMX for gr3s32 is 80.0, and changed to 70
# rate constant for equilibrating shoot-root nonstructural C concentration                            : PTSHT for gr3s32 is 0.003000000026077032, and changed to 0.02
# hour requirement for autumn leafoff                                                                 : VRNXI for gr3s32 is 720.0, and changed to 1200
# leaf length vs width ratio                                                                          : WDLF for gr3s32 is 5.0, and changed to 20
# ...

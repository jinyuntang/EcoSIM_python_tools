# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc'
micparfile='/Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/MicrobePars.20260211.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)

# %%
#how to 

pft='maiz31'
chl0=0.08
pars={'VCMX4':1000,'UPKMZH':5,'UPKMZO':10,'XRNI':0.005,'XRLA':0.005,'ETMX':1000,'SLA1':0.015,'GROUPX':7,
      'GRDM':0.15,'UPMXZO':5.e-3,'UPMXZH':2.5e-3,'RUBP':0.10,'PEPC':0.05,'CHL':0.35,'fCHLMESO':0.6,
      'RTFQ':600,'PR':0.1,'PORT':0.15,'RRAD1M':0.5e-3,'RRAD2M':0.05e-3,'VCMX':65,
      'PTSHT':0.04,'RSRR':5.e7/3600,'RSRA':5.e11/3600,'FCO2':0.4,'CNWL':2.7,'CPWL':35,'CNWR':2.2,'CPWR':20,
      'ANGBR':90,'ANGSH':60,'WDLF':10,'PhiMEAN':0.10,'GRW2L':0.66,'OSMO':-1.5}
print(pft)

parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
#ParamModify(parfile,pft,parnm,0.8)
#parnm='RSRR'
#parnm='RSRA'
pft='soyb31'
pars={'XRNI':0.005,'XRLA':0.005,'XTLI':2.,'VCMX':60,'VOMX':12.,'ETMX':600,'VRNLI':24,'GRDM':0.08,'PORT':0.05,'SLA1':0.03,'GROUPX':5,
      'OSMO':-1.5,'UPMXZO':2.e-3,'UPMXZH':5.e-3,'RUBP':0.35,'CHL':0.20,'RTFQ':400,'PR':0.1,'PTSHT':0.04,'RRAD1M':0.4e-4,
      'RRAD2M':0.04e-3,'RSRR':2.5e7/3600,'RSRA':2.7e12/3600,'CNWL':2.8,'CPWL':40,'CNWR':2.4,'CPWR':25,'FCO2':0.7,'WDLF':1.5,
     'ANGBR':45,'ANGSH':60,'SDMX':4,'PhiMAX':0.30,'PhiMIN':0.15,'ROOTMAGE':480,'R95MAT':4e-3,'GRW2L':0.9,'CPRTLIG':0.002,'ZTYPI':2.5}
print(pft)
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# maiz31
# /Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc
# rate of node initiation at 25oC                                                                     : XRNI for maiz31 is 0.003000000026077032, and changed to 0.005
# initial plant maturity group, aka minimum number of vegetative nodes initiated before floral        : GROUPX for maiz31 is 6.0, and changed to 7
# soyb31
# /Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc

# %%
print(23*.35)
# Out:
# 8.049999999999999

# %%
print(24+16+45+72+46+42)
# Out:
# 245

# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.ParamEditor import ParEditor

#how to 
parfile='/Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc'
micparfile='/Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/MicrobePars.20260211.nc'
parEditor=ParEditor(pftparfile=parfile,micparfile=micparfile)
#parEditor.CopyPlantPft('soyb31','soyb41')
#compare two pfts

# %%
#how to 
parEditor=ParEditor(pftparfile=parfile)
pft='gr3a35'
pars={'IEBTYP':3}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)

pft='maiz41' #based on ponderosa pine
pars={'VCMX4':400,'UPKMZH':5,'UPKMZO':10,'XRNI':0.013,'XRLA':0.025,'ETMX':2000,'SLA1':0.020,'GROUPX':13,
      'GRDM':0.15,'UPMXZO':5.e-3,'UPMXZH':2.5e-3,'RUBP':0.1,'PEPC':0.12,'CHL':0.20,'fCHLMESO':0.6,
      'RTFQ':600,'PR':0.1,'PORT':0.15,'RRAD1M':0.5e-3,'RRAD2M':0.05e-3,'VCMX':45,'IEBTYP':3,'SNL1':0.1,
      'PTSHT':0.02,'RSRR':5.e7/3600,'RSRA':5.e11/3600,'FCO2':0.4,'CNWL':2.7,'CPWL':35,'CNWR':2.2,'CPWR':20,
      'ANGBR':90,'ANGSH':60,'WDLF':10,'PhiMEAN':0.10,'GRW2L':0.66,'ZTYPI':2.0,'VRNLI':360,'VRNXI':360}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)

pft='soyb41'
pars={'XRNI':0.013,'XRLA':0.02,'XTLI':4.,'VCMX':60,'VOMX':12.,'ETMX':550,'VRNLI':240,'GRDM':0.08,'PORT':0.05,'SLA1':0.015,'GROUPX':12,
      'OSMO':-1.7,'UPMXZO':2.e-3,'UPMXZH':5.e-3,'RUBP':0.35,'CHL':0.30,'RTFQ':400,'PR':0.1,'PTSHT':0.02,'RRAD1M':0.4e-4,'IEBTYP':4,
      'RRAD2M':0.04e-3,'RSRR':2.5e7/3600,'RSRA':2.7e12/3600,'CNWL':2.8,'CPWL':40,'CNWR':2.4,'CPWR':25,'FCO2':0.7,'WDLF':1.5,'SSL1':0.5,
     'ANGBR':45,'ANGSH':60,'SDMX':4,'PhiMAX':0.30,'PhiMIN':0.15,'ROOTMAGE':480,'R95MAT':4e-3,'GRW2L':0.9,'CPRTLIG':0.002,'ZTYPI':2.0}
parEditor.PlantParamModify(pft,pars,iscale=False,verbose=True)
# Out:
# /Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc
# Embrophyte type                                                                                     : IEBTYP for gr3a35 is 1, and changed to 3
# /Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc
# /Users/jinyuntang/work/github/ecosim_workspace/benchmark/code/input_data/ecosim_pftpar_20260303.nc

# %%
print(0.4166666667*24)
# Out:
# 10.0000000008

# %%
print(0.8*3.3)
# Out:
# 2.64
